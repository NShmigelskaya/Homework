# %% [markdown]
#   # $\S1$  * Движение точки*

# %% [markdown]
# ## Задача № 1.31:
# ### $\underline{Условие:}$ в задаче преследования убегающий **$A$** движется по прямой с постоянной скоростью **$v_1$**. Догоняющий **$B$** движется с постоянной скоростью **$v_2$**, направленной по **$AB$**. Найти уравнение траектории сближения **$AB = r(\varphi)$** в системе отсчёта, связанной с убегающим, если  **$\varphi \neq 0 $**.
# ### $\underline{Рисунок:}$
# ![%D0%91%D0%B5%D0%B7%D1%8B%D0%BC%D1%8F%D0%BD%D0%BD%D1%8B%D0%B9.jpg](attachment:%D0%91%D0%B5%D0%B7%D1%8B%D0%BC%D1%8F%D0%BD%D0%BD%D1%8B%D0%B9.jpg)

# %% [markdown]
#  #### Рассмотрим проекции на орты **$e_φ$** и **$e_ρ$**:
#  проекция на **$e_ρ$**:

# %% [markdown]
# #### **$-v_2 + v_1cos(\varphi)$**

# %%
from sympy import *
init_printing()
import math
v1=Symbol('v1')
v2=Symbol('v2')
φ=Symbol('φ')
p=Symbol('p')

# %% [markdown]
# #### **$-v_2 + v_1cos(\varphi) = \dotρ$**

# %% [markdown]
# проекция на ось **$e_φ$**:

# %% [markdown]
# #### **$-v_1sin(φ)$**

# %% [markdown]
# #### **$-v_1sin(\varphi) = ρ\dotφ$**
# #### найдём отношение проекций:
# ### **${{\dotρ}\over{ρ\dotφ}}={{-v_2 + v_1cos(\varphi)}\over{-v_1sin(φ)}}$**
# ### **${{dρ}\over{ρ}}={{-v_2 + v_1cos(\varphi)}\over{-v_1sin(φ)}}{\scriptsize dφ}$**
# ### **$\int\limits_{ρ_0}^ρ{{dρ}\over{ρ}}=\int\limits_{φ_0}^φ{{-v_2 + v_1cos(\varphi)}\over{-v_1sin(φ)}}{\scriptsize dφ}\;\;\; $**
# #### найдём интегралы левой и правой части:

# %%
p1=Symbol('p1')
p2=Symbol('p2')
a=Integral(p**(-1),p)
integrate(p**(-1),(p,p1,p2))
# Out:
# -log(p₁) + log(p₂)

# %%
φ1=Symbol('φ1')
φ2=Symbol('φ2')
b=Integral((-v2+v1*cos(φ))/(-v1+sin(φ)),φ)
integrate((v2/(v1*sin(φ))-tan(φ)),(φ,φ1,φ2))
# Out:
#                                              ⎛log(cos(φ1) - 1)   log(cos(φ1) +
#      ⎛   2        ⎞      ⎛   2        ⎞   v₂⋅⎜──────────────── - ─────────────
#   log⎝sin (φ1) - 1⎠   log⎝sin (φ2) - 1⎠      ⎝       2                  2
# - ───────────────── + ───────────────── - ────────────────────────────────────
#           2                   2                              v₁
#
#  1)⎞      ⎛log(cos(φ2) - 1)   log(cos(φ2) + 1)⎞
# ───⎟   v₂⋅⎜──────────────── - ────────────────⎟
#    ⎠      ⎝       2                  2        ⎠
# ──── + ────────────────────────────────────────
#                           v₁

# %% [markdown]
# #### После вычислений получим:
# ### **$ln\bigg|{{ρ}\over{ρ_0}}\bigg|={{v_2}\over{v_1}}ln\bigg|{{tg({{φ}\over{2}}))}\over{tg({{φ_0}\over{2}})}}\bigg|-ln\bigg|{{sin(φ)}\over{sin(φ_0)}}\bigg|+C$**
# ### **$ρ={ρ_0}e^{\bigg(ln\bigg|{{tg({{φ}\over{2}}))}\over{tg({{φ_0}\over{2}})}}\bigg|^{{{v_2}\over{v_1}}}-\,\,ln\bigg{|}{{sin(φ)}\over{sin(φ_0)}}\bigg|\bigg)}$**
# ### **$ρ=ρ_0{{tg({{φ}\over{2}}))}\over{tg({{φ_0}\over{2}})}}^{{{v_2}\over{v_1}}}\cdot{{sin(φ_0)}\over{sin(φ)}}$**
# ### Ответ: **$p_0{{tg({{φ}\over{2}}))}\over{tg({{φ_0}\over{2}})}}^{{{v_2}\over{v_1}}}\cdot{{sin(φ_0)}\over{sin(φ)}}$**
